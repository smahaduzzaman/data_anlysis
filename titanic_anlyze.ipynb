# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds = pd.read_csv('train.csv')
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import seaborn as sns

# %%
sns.countplot('Sex')
# Out:
# <Axes: xlabel='count'>

# %%
sns.countplot('Sex', data = ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sns.countplot('Sex', data = ds)
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
sns.countplot(x='Sex', data=ds)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
ds['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex', data = ds, hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Ticket', data=ds)
# Out:
# <Axes: xlabel='Ticket', ylabel='count'>

# %%
ds['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
sns.countplot(x='Pclass', data=ds)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
ds['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data=ds, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Pclass', data = ds, hue = 'Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='SibSp', data = ds)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
ds['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
sns.countplot(x='SibSp', data = ds, hue = 'Survived')
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
ds.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
sns.lmplot(x='Age', y='Survived', data=ds)

# %%
sns.lmplot(x='Age', y='Survived', data=ds, hue='Pclass')

# %%
sns.countplot(x='Embarked',  data = ds)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x='Embarked',  data = ds, hue='Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
ds['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
sns.countplot(x='Embarked', data=ds, hue='Survived', palette='husl')
plt.title('Count of Survivors by Embarked')

plt.subplot(1, 2, 2)
sns.countplot(x='Embarked', data=ds, hue='Survived', palette='husl', dodge=False)
plt.title('Count of Non-Survivors by Embarked')

plt.tight_layout()
plt.show()

# %%
embarked_counts = ds['Embarked'].value_counts()
embarked_counts
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
multiple_counts = ds[['Embarked', 'Survived']].value_counts()
multiple_counts
# Out:
# Embarked  Survived
# S         0           427
#           1           217
# C         1            93
#           0            75
# Q         0            47
#           1            30
# Name: count, dtype: int64

# %%
whole_counts = ds.value_counts()
whole_counts
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %%
plt.figure(figsize=(8, 6))
plt.pie(embarked_counts, labels=embarked_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Embarked')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 6))
embarked_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Embarked')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
cabin_counts = ds['Cabin'].value_counts()
cabin_counts
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
plt.figure(figsize=(12, 6))
cabin_counts.plot(kind='bar', color='lightgreen')
plt.title('Distribution of Cabin')
plt.xlabel('Cabin')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
